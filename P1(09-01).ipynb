# %%
# !pip install opencv-python

# %%
from matplotlib.image import imread
import  matplotlib.pyplot as plt
import cv2

# %%
lena = cv2.imread(r'C:\Users\student.DESKTOP-QD7EIN4\Desktop\510009\lena.png')
lena = cv2.cvtColor(lena, cv2.COLOR_BGR2RGB)
r,g,b= lena[:,:,0],lena[:,:,1],lena[:,:,2]
gamma =1
r_const,g_const,b_const=0.2126,0.7152,0.0722
lena_gray = (r_const*r**gamma)+(g_const*g**gamma)+(b_const*b**gamma)
plt.figure(figsize=(10,10))
fig=plt.figure(1)
img1,img2=fig.add_subplot(121),fig.add_subplot(122)
img1.imshow(lena)
img2.imshow(lena_gray,plt.colormaps["grey"])
cv2.imwrite('lenagrey.jpg',lena_gray)
# Out:
# True

# %%
sr = cv2.imread(r'C:\Users\student.DESKTOP-QD7EIN4\Desktop\510009\sr.png')
sr= cv2.cvtColor(sr, cv2.COLOR_BGR2RGB)
r,g,b= sr[:,:,0],sr[:,:,1],sr[:,:,2]
gamma =1
r_const,g_const,b_const=0.2126,0.7152,0.0722
sr_gray = (r_const*r**gamma)+(g_const*g**gamma)+(b_const*b**gamma)
plt.figure(figsize=(10,10))
fig=plt.figure(1)
img1,img2=fig.add_subplot(121),fig.add_subplot(122)
img1.imshow(sr)
img2.imshow(sr_gray,plt.colormaps["grey"])
cv2.imwrite('srgrey.jpg',sr_gray)
# Out:
# True

# %%
import cv2
import  matplotlib.pyplot as plt

lena = cv2.imread(r'C:\Users\student.DESKTOP-QD7EIN4\Desktop\510009\lena.png')
lena = cv2.cvtColor(lena, cv2.COLOR_RGB2BGR)
lena_gray =  cv2.cvtColor(lena, cv2.COLOR_BGR2GRAY)

plt.figure(figsize=(10,10))
fig=plt.figure(1)
img1,img2=fig.add_subplot(121),fig.add_subplot(122)
img1.imshow(lena)
img2.imshow(lena_gray,plt.colormaps["grey"])

# %%
sr = cv2.imread(r'C:\Users\student.DESKTOP-QD7EIN4\Desktop\510009\sr.png')
sr = cv2.cvtColor(sr, cv2.COLOR_BGR2RGB)
sr_gray =  cv2.cvtColor(sr, cv2.COLOR_RGB2GRAY)
plt.figure(figsize=(10,10))
fig=plt.figure(1)
img1,img2=fig.add_subplot(121),fig.add_subplot(122)
img1.imshow(sr)
img2.imshow(sr_gray,plt.colormaps["grey"])

# %%
import cv2
from matplotlib import pyplot as plt

# Load the greyscale image and apply histogram equalization
lena = cv2.imread(r'C:\Users\student.DESKTOP-QD7EIN4\Desktop\510009\lena.png', cv2.IMREAD_GRAYSCALE)
equi_lena = cv2.equalizeHist(lena)

# Calculate the histograms
o_hist = cv2.calcHist([lena], [0], None, [256], [0, 256])
equi_hist = cv2.calcHist([equi_lena], [0], None, [256], [0, 256])

# Plot the images and histograms
plt.figure(figsize=(12, 8))

# Original image
plt.subplot(2, 2, 1)
plt.imshow(lena, cmap='gray')
plt.title('Original Image')
plt.axis('off')

# Histogram of original image
plt.subplot(2, 2, 2)
plt.plot(o_hist, color='black')
plt.title('Histogram of Original Image')
plt.xlim([0, 256])
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')

# Equalized image
plt.subplot(2, 2, 3)
plt.imshow(equi_lena, cmap='gray')
plt.title('Equalized Image')
plt.axis('off')

# Histogram of equalized image
plt.subplot(2, 2, 4)
plt.plot(equi_hist, color='black')
plt.title('Histogram of Equalized Image')
plt.xlim([0, 256])
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
import cv2
from matplotlib import pyplot as plt

# Load the greyscale image and apply histogram equalization
sr = cv2.imread(r'C:\Users\student.DESKTOP-QD7EIN4\Desktop\510009\sr.png', cv2.IMREAD_GRAYSCALE)
equi_sr = cv2.equalizeHist(sr)

# Calculate the histograms
o_hist = cv2.calcHist([sr], [0], None, [256], [0, 256])
equi_hist = cv2.calcHist([equi_sr], [0], None, [256], [0, 256])

# Plot the images and histograms
plt.figure(figsize=(12, 8))

# Original image
plt.subplot(2, 2, 1)
plt.imshow(sr, cmap='gray')
plt.title('Original Image')
plt.axis('off')

# Histogram of original image
plt.subplot(2, 2, 2)
plt.plot(o_hist, color='black')
plt.title('Histogram of Original Image')
plt.xlim([0, 256])
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')

# Equalized image
plt.subplot(2, 2, 3)
plt.imshow(equi_sr, cmap='gray')
plt.title('Equalized Image')
plt.axis('off')

# Histogram of equalized image
plt.subplot(2, 2, 4)
plt.plot(equi_hist, color='black')
plt.title('Histogram of Equalized Image')
plt.xlim([0, 256])
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread(r'C:\Users\admin\Desktop\summa\lena.png', 1)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
# Loading the image

half = cv2.resize(image, (0, 0), fx = 0.1, fy = 0.1)
bigger = cv2.resize(image, (2160, 2160))

stretch_near = cv2.resize(image, (780, 540), 
               interpolation = cv2.INTER_LINEAR)


Titles =["Original", "Half", "Bigger", "Interpolation Nearest"]
images =[image, half, bigger, stretch_near]
count = 4


plt.figure(figsize=(12, 8))

for i in range(4):
    plt.subplot(2, 2, i + 1)
    plt.imshow(images[i])
    plt.title(Titles[i])

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread(r'C:\Users\admin\Desktop\summa\sr.png', 1)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
# Loading the image

half = cv2.resize(image, (0, 0), fx = 0.5, fy = 0.5)
bigger = cv2.resize(image, (1050, 1610))

stretch_near = cv2.resize(image, (780, 540), 
               interpolation = cv2.INTER_LINEAR)


Titles =["Original", "Half", "Bigger", "Interpolation Nearest"]
images =[image, half, bigger, stretch_near]

plt.figure(figsize=(12, 8))

for i in range(4):
    plt.subplot(2, 2, i + 1)
    plt.imshow(images[i])

    plt.title(Titles[i])

# %%
import numpy as np
import matplotlib.pyplot as plt
def histogram_equalization(image):
    # Flatten the image array and calculate the histogram
    hist, bins = np.histogram(image.flatten(), 256, [0, 256])

    # Compute the cumulative distribution function (CDF)
    cdf = hist.cumsum()

    # Normalize the CDF
    cdf_normalized = cdf * hist.max() / cdf.max()

    # Use linear interpolation of the CDF to find new pixel values
    cdf_m = np.ma.masked_equal(cdf, 0)
    cdf_m = (cdf_m - cdf_m.min()) * 255 / (cdf_m.max() - cdf_m.min())
    cdf = np.ma.filled(cdf_m, 0).astype('uint8')

    # Map the pixel values using the normalized CDF
    equalized_image = cdf[image]

    return equalized_image

# Load the image (replace with your image loading code)
image = plt.imread(r'C:\Users\admin\Desktop\summa\lena.png')

# Convert to grayscale if it's a color image
if len(image.shape) == 3:
    image = np.dot(image[..., :3], [0.2989, 0.5870, 0.1140])

# Perform histogram equalization
equalized_image = histogram_equalization(image.astype(np.uint8))

# Display the original and equalized images
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(image, cmap='gray')
plt.title('Original Image')

plt.subplot(1, 2, 2)
plt.imshow(equalized_image, cmap='gray')
plt.title('Equalized Image')

plt.show()
# Out:
# Traceback (most recent call last):
#
#   File ~\anaconda3\envs\datasciencelab\Lib\site-packages\IPython\core\interactiveshell.py:3577 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[20], line 24
#     image = plt.imread(r'C:\Users\admin\Desktop\summa\lena.png')
#
#   File ~\anaconda3\envs\datasciencelab\Lib\site-packages\matplotlib\pyplot.py:2404 in imread
#     return matplotlib.image.imread(fname, format)
#
#   File ~\anaconda3\envs\datasciencelab\Lib\site-packages\matplotlib\image.py:1525 in imread
#     with img_open(fname) as image:
#
#   File ~\anaconda3\envs\datasciencelab\Lib\site-packages\PIL\ImageFile.py:138 in __init__
#     self._open()
#
#   File ~\anaconda3\envs\datasciencelab\Lib\site-packages\PIL\PngImagePlugin.py:732 in _open
#     raise SyntaxError(msg)
#
#   File <string>
# SyntaxError: not a PNG file

# %%
import numpy as np
import cv2

def my_float2int(img):
    
    # Don't use *255 twice
    # img = np.round(img * 255, 0)
    img = np.round(img, 0)
    img = np.minimum(img, 255)
    img = np.maximum(img, 0)
    img = img.astype('uint8')
    
    return img

def equalizeHistogram(img):
    
    img_height = img.shape[0]
    img_width = img.shape[1]
    histogram = np.zeros([256], np.int32) 
    
    
    # calculate histogram 
    for i in range(0, img_height):
        for j in range(0, img_width):
            histogram[img[i, j]] +=1
            
    # calculate pdf of the image
    pdf_img = histogram / histogram.sum()
    
    ### calculate cdf 
    # cdf initialize . 
    # Why does the type np.int32?
    #cdf = np.zeros([256], np.int32)
    cdf = np.zeros([256], float)

    # For loop for cdf
    for i in range(0, 256):
        for j in range(0, i+1):
            cdf[i] += pdf_img[j]

    # You may implement the "accumulated sum" in a more efficient way:
    cdf = np.zeros(256, float)
    cdf[0] = pdf_img[0]
    for i in range(1, 256):
        cdf[i] = cdf[i-1] + pdf_img[i]
     
    cdf_eq = np.round(cdf * 255, 0) # mapping, transformation function T(x)
    
    imgEqualized = np.zeros((img_height, img_width))
    
    # for mapping input image to s.
    for i in range(0, img_height):
        for j in range(0, img_width):
            r = img[i, j] # feeding intensity levels of pixels into r. 
            s = cdf_eq[r] # finding value of s by finding r'th position in the cdf_eq list.
            imgEqualized[i, j] = s # mapping s thus creating new output image.
            
    # calculate histogram equalized image here
    # imgEqualized = s # change this
    
    return imgEqualized

# end of function


# Read input image as Grayscale
img_low = cv2.imread(r'C:\Users\admin\Desktop\summa\lena.png', cv2.IMREAD_GRAYSCALE)

# 2.2 obtain the histogram equalized images using the above function
img_eq_low = equalizeHistogram(img_low)
img_eq_low = my_float2int(img_eq_low)

# Use cv2.imshow (instead of plt.imshow) just for testing.
cv2.imshow('img_eq_low', img_eq_low)
cv2.waitKey()
# Out:
# -1
